# %%
import pandas as pd 
import numpy as np 
import yfinance as yf 
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("./data/data.csv")

# %%
data.head(3)
# Out:
#    Unnamed: 0  Adj Close  40 period ADX.        AO      UPPER      LOWER  \
# 0           0  16.407499       14.309929  0.182759  16.689889  16.054189
# 1           1  16.260000       14.140038  0.171225  16.685534  16.049697
# 2           2  16.194000       14.107290  0.141156  16.674920  16.039176
#
#    40 period ATR      Buy.     Sell.    Buy..1  ...  SIGNAL.3        VZO  \
# 0       0.153630  0.497433  1.605319  1.443633  ...  0.039537  12.117903
# 1       0.154255  0.114767  1.950409  1.317071  ...  0.041372   7.085278
# 2       0.155231  0.710949  0.801172  1.259344  ...  0.040254   2.478898
#
#    40 Williams %R  40 period WMA.          WOBV       WT1.       WT2.  \
# 0      -33.487389       16.251470  9.670663e+06  20.127102  18.448995
# 1      -45.734591       16.251063  9.382564e+06  15.500417  18.108371
# 2      -51.990512       16.247949  9.259769e+06   6.009721  14.930795
#
#    40 period ZLEMA       pct  pct_shifted
# 0        16.353788  0.034847     0.027954
# 1        16.356737  0.031090     0.034847
# 2        16.351900  0.018428     0.031090
#
# [3 rows x 118 columns]

# %%
data = data[data.columns[1:]]

# %%
data.head(5)
# Out:
#    Adj Close  40 period ADX.        AO      UPPER      LOWER  40 period ATR  \
# 0  16.407499       14.309929  0.182759  16.689889  16.054189       0.153630
# 1  16.260000       14.140038  0.171225  16.685534  16.049697       0.154255
# 2  16.194000       14.107290  0.141156  16.674920  16.039176       0.155231
# 3  15.938425       14.454950  0.058470  16.642213  16.003133       0.165355
# 4  16.002501       14.790423 -0.025260  16.618224  15.975358       0.166168
#
#        Buy.     Sell.    Buy..1   Sell..1  ...  SIGNAL.3        VZO  \
# 0  0.497433  1.605319  1.443633  1.222444  ...  0.039537  12.117903
# 1  0.114767  1.950409  1.317071  1.291776  ...  0.041372   7.085278
# 2  0.710949  0.801172  1.259344  1.245051  ...  0.040254   2.478898
# 3  4.036733  4.127643  1.523862  1.519588  ...  0.031022  -4.524090
# 4  2.714474  0.098184  1.637256  1.384214  ...  0.019899   1.134482
#
#    40 Williams %R  40 period WMA.          WOBV       WT1.       WT2.  \
# 0      -33.487389       16.251470  9.670663e+06  20.127102  18.448995
# 1      -45.734591       16.251063  9.382564e+06  15.500417  18.108371
# 2      -51.990512       16.247949  9.259769e+06   6.009721  14.930795
# 3      -74.593351       16.232945  8.488516e+06  -8.516856   8.280096
# 4      -67.875707       16.221917  8.642566e+06 -17.888593  -1.223828
#
#    40 period ZLEMA       pct  pct_shifted
# 0        16.353788  0.034847     0.027954
# 1        16.356737  0.031090     0.034847
# 2        16.351900  0.018428     0.031090
# 3        16.319218 -0.003202     0.018428
# 4        16.288813  0.022687    -0.003202
#
# [5 rows x 117 columns]

# %%
# max of columns
print(data.describe().iloc[-1].astype("int32").to_numpy())
# Out:
# [        91         35          7         90         86          2
#          29         37          3          5         91         85
#          83          0          0        321   59353476   48237308
#          88         88         47         41         88         41
#          60         87         89         91          5          4
#    10746093         86          0        100         84         18
#          17          8         90         56         89         89
#          87         91          0         88         89         83
#         208          2          2         79         36         89
#          88         88         16          6  936570702          1
#          90         90         88         88         88         92
#          92         94         95         90         90         89
#          88         88         91         92         92         93
#           5          4          2         91         53         51
#          73         91         85         85         84         84
#         100        100          0         89         90          6
#           0         71         86         -7         22          1
#           1 1096283300         45          3          2         55
#           0         87   63025128         84         83         89
#           0          0]

# %%
data.columns.to_numpy()[17]
# Out:
# 'MFV.1'

# %%
# from sklearn.preprocessing import StandardScaler
# standarts = [ StandardScaler() for i in data.columns]
# # sc = StandardScaler()
# for i in range(len(standarts)):
#     print(i)
#     data[data.columns[i]] = standarts[i].fit_transform(data[data.columns[i]].reshape([-1,1])).reshape([-1])
# # cols = data.columns
# # data[cols] = sc.fit_transform(data[cols])

# %%
sorted(data.describe().iloc[-1].tolist())
# Out:
# [-7.227062758381791,
#  -0.0,
#  0.437677825797646,
#  0.5908871732407683,
#  0.5908871732407683,
#  0.7220184058214025,
#  0.743285481445477,
#  0.8282498635620847,
#  0.917529566236021,
#  0.9996326542145864,
#  1.2284725138126469,
#  1.3223564160919072,
#  1.485928929400656,
#  2.219649936698375,
#  2.4229391218190983,
#  2.613997650146485,
#  2.670329342272953,
#  2.874431366651053,
#  3.212990084444357,
#  3.9505555127011047,
#  4.309568379266992,
#  4.615461461593695,
#  5.0053735112713005,
#  5.453169046324188,
#  5.637829114597281,
#  6.420600891113281,
#  6.458250887994088,
#  7.039234677483051,
#  8.230397571568457,
#  16.2510986328125,
#  17.47752815232811,
#  18.433297722997004,
#  22.257231442189426,
#  29.35103987422809,
#  35.84941849347198,
#  36.63682309095152,
#  37.04018883579471,
#  41.31961237060664,
#  41.59885703906274,
#  45.18444168087156,
#  47.39608412282503,
#  51.61599506107672,
#  53.95716519807522,
#  55.604988453288215,
#  56.77744677419223,
#  60.43942178435125,
#  71.23233402440297,
#  73.92754246506253,
#  79.37949906472294,
#  83.331104083208,
#  83.76713682152851,
#  83.95765201680932,
#  84.33119750189769,
#  84.33119750189769,
#  84.4799074031232,
#  84.58306492491319,
#  85.55749893188477,
#  85.99558734893799,
#  85.99558734893799,
#  86.30566619367683,
#  86.58040292534876,
#  86.6596782004112,
#  87.08129869786704,
#  87.92252349853516,
#  87.94999694824219,
#  88.06587169102211,
#  88.14981079101564,
#  88.3008426319469,
#  88.40820821126303,
#  88.4832472635905,
#  88.5937115151497,
#  88.5983560735529,
#  88.7621090036105,
#  88.79666392008464,
#  88.79666392008464,
#  88.85848007202148,
#  89.20034726377213,
#  89.30965485776838,
#  89.58549485270183,
#  89.66425903375614,
#  89.67000198364258,
#  89.68729384737556,
#  89.81499862670898,
#  89.94198829843057,
#  90.043332417806,
#  90.0728354288737,
#  90.52774482988822,
#  90.86166636149088,
#  90.86166636149088,
#  90.86166636149088,
#  90.88997193131704,
#  91.02674612893074,
#  91.29000091552734,
#  91.29000091552734,
#  91.65049729410808,
#  91.68000030517578,
#  91.68000030517578,
#  91.68000030517578,
#  92.10833485921223,
#  92.13783787027997,
#  92.92666880289714,
#  92.92666880289714,
#  93.71549973551431,
#  94.1733373006185,
#  95.42000579833986,
#  100.0,
#  100.0,
#  100.0,
#  208.22036499735384,
#  321.9008931524612,
#  10746093.26872558,
#  48237308.611002445,
#  59353476.40548341,
#  63025128.76585102,
#  936570702.0,
#  1096283300.5681946]

# %%
data = data.drop("MFV",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 data = data.drop("MFV",axis=1)
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['MFV'] not found in axis"

# %%
data = data.drop(data.columns[data.max() > 100],axis=1)

# %%
data.shape
# Out:
# (4959, 109)

# %% [raw]
# data.isna()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 normalized_data = normalized_data.drop("40 Williams %R",axis=1)
#
# NameError: name 'normalized_data' is not defined

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (4959, 109)

# %%
data = data.astype("float64")
maxes = data.max().to_numpy().reshape([-1])
cols = data.columns.to_numpy().reshape([-1])
normalized_data=data/data.max()
normalized_data = normalized_data.drop("40 Williams %R",axis=1)
# normalized_data=(df-df.mean())/df.std()

# %%
normalized_data.describe()
# Out:
#          Adj Close  40 period ADX.           AO        UPPER        LOWER  \
# count  4959.000000     4959.000000  4959.000000  4959.000000  4959.000000
# mean      0.458696        0.442649     0.004168     0.478992     0.466014
# std       0.220878        0.162555     0.287482     0.228397     0.228289
# min       0.090919        0.178354    -1.606029     0.112598     0.073897
# 25%       0.265801        0.320566    -0.127384     0.276960     0.271675
# 50%       0.436231        0.415461     0.041554     0.459914     0.440139
# 75%       0.605273        0.539055     0.167901     0.633589     0.620132
# max       1.000000        1.000000     1.000000     1.000000     1.000000
#
#        40 period ATR         Buy.        Sell.       Buy..1      Sell..1  ...  \
# count    4959.000000  4959.000000  4959.000000  4959.000000  4959.000000  ...
# mean        0.305015     0.041093     0.032626     0.305510     0.241465  ...
# std         0.171150     0.059488     0.053154     0.104342     0.100638  ...
# min         0.035031     0.000000     0.000000     0.123559     0.063010  ...
# 25%         0.187700     0.009480     0.006007     0.232721     0.170517  ...
# 50%         0.278238     0.021397     0.015433     0.284432     0.220749  ...
# 75%         0.398567     0.047559     0.036029     0.351510     0.287943  ...
# max         1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#              VWAP.       MACD.2     SIGNAL.3          VZO  40 period WMA.  \
# count  4959.000000  4959.000000  4959.000000  4959.000000     4959.000000
# mean      0.614771     0.030516     0.034026     0.074128        0.480555
# std       0.223091     0.236282     0.247182     0.326323        0.231105
# min       0.341104    -0.953241    -0.925944    -1.124593        0.109855
# 25%       0.406355    -0.091444    -0.088649    -0.155335        0.278822
# 50%       0.556027     0.046257     0.050123     0.078372        0.462093
# 75%       0.804806     0.165744     0.177496     0.314166        0.633753
# max       1.000000     1.000000     1.000000     1.000000        1.000000
#
#               WT1.         WT2.  40 period ZLEMA          pct  pct_shifted
# count  4959.000000  4959.000000      4959.000000  4959.000000  4959.000000
# mean      0.119396     0.120100         0.468843     0.026258     0.026250
# std       0.471349     0.468696         0.226268     0.225231     0.225230
# min      -0.966226    -0.954455         0.098550    -0.958522    -0.958522
# 25%      -0.279005    -0.272697         0.270980    -0.086060    -0.086060
# 50%       0.166842     0.169810         0.445355     0.060397     0.060330
# 75%       0.546950     0.547341         0.620842     0.166930     0.166930
# max       1.000000     1.000000         1.000000     1.000000     1.000000
#
# [8 rows x 108 columns]

# %%
maxes
# Out:
# array([ 91.29000092,  35.84941849,   7.03923468,  90.52774483,
#         86.6596782 ,   2.61399765,  29.35103987,  37.04018884,
#          3.95055551,   5.00537351,  91.02674613,  85.99558735,
#         83.33110408,   0.74328548,   0.99963265,  88.30084263,
#         88.59835607,  47.39608412,  41.59885704,  88.59371152,
#         41.31961237,  60.43942178,  87.94999695,  89.81499863,
#         91.68000031,   5.63782911,   4.30956838,  86.30566619,
#          0.72201841, 100.        ,  84.58306492,  18.43329772,
#         17.47752815,   8.23039757,  90.88997193,  56.77744677,
#         89.68729385,  89.67000198,  87.9225235 ,  91.29000092,
#          0.91752957,  88.762109  ,  89.9419883 ,  83.76713682,
#          2.42293912,   2.21964994,  79.37949906,  36.63682309,
#         89.66425903,  88.85848007,  88.06587169,  16.25109863,
#          6.45825089,   1.48592893,  90.86166636,  90.04333242,
#         88.79666392,  88.40820821,  88.14981079,  92.10833486,
#         92.9266688 ,  94.1733373 ,  95.4200058 ,  90.86166636,
#         90.07283543,  89.58549485,  88.79666392,  88.48324726,
#         91.65049729,  92.13783787,  92.9266688 ,  93.71549974,
#          5.45316905,   4.61546146,   2.67032934,  91.68000031,
#         53.9571652 ,  51.61599506,  73.92754247,  91.68000031,
#         85.99558735,  85.55749893,  84.3311975 ,   1.        ,
#         84.3311975 , 100.        , 100.        ,   0.82824986,
#         89.20034726,  90.86166636,   6.42060089,   0.43767783,
#         71.23233402,  86.58040293,  -7.22706276,  22.25723144,
#          1.22847251,   1.32235642,  45.18444168,   3.21299008,
#          2.87443137,  55.60498845,  -0.        ,  87.0812987 ,
#         84.4799074 ,  83.95765202,  89.30965486,   0.59088717,
#          0.59088717])

# %%
normalized_data['Adj Close'].plot()
window_size = 60
trainTestSplit=.9

# %%
window_size = 60
data_arr = normalized_data.to_numpy()
X = []
y = []
for i in range(0,len(data_arr)-window_size):
    X.append(data_arr[i:i+window_size])
    y.append(data_arr[i+window_size,0])
X = np.array(X)
y = np.array(y)
print("X shape: ",X.shape)
print("y shape: ",y.shape)
# Out:
# X shape:  (4899, 60, 108)
# y shape:  (4899,)

# %%
index = int(len(X) * .9)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Out:
# (490, 60, 108)

# %%
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import LSTM,Dense,Dropout,GRU,Flatten

# %%
# import keras.losses
# keras.losses.smape_loss = smape_loss
# import tensorflow.keras.backend as K

# def smape_loss(y_true, y_pred):
#     epsilon = 0.1
#     summ = K.maximum(K.abs(y_true) + K.abs(y_pred) + epsilon, 0.5 + epsilon)
#     smape = K.abs(y_pred - y_true) / summ * 2.0
#     return smape * 100.0
# model = load_model("./models/goodModelDividedByMaxAdjClose.h5",custom_objects={"smape_loss":smape_loss})

# %%
model = Sequential()

# %%
model.add(LSTM(64,input_shape=X_train[0].shape,return_sequences=True))
model.add(Dropout(.2))

# %%
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(.2))

# %%
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(.2))

# %%
model.add(LSTM(64,return_sequences=False))
model.add(Dropout(.2))

# %%
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 64)            44288
#
#  dropout (Dropout)           (None, 60, 64)            0
#
#  lstm_1 (LSTM)               (None, 60, 64)            33024
#
#  dropout_1 (Dropout)         (None, 60, 64)            0
#
#  lstm_2 (LSTM)               (None, 60, 64)            33024
#
#  dropout_2 (Dropout)         (None, 60, 64)            0
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 145,473
# Trainable params: 145,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow.keras.backend as K

def smape_loss(y_true, y_pred):
    epsilon = 0.1
    summ = K.maximum(K.abs(y_true) + K.abs(y_pred) + epsilon, 0.5 + epsilon)
    smape = K.abs(y_pred - y_true) / summ * 2.0
    return smape * 100.0
model.compile(optimizer='adam',loss='mse',metrics=['mae','mse','mean_absolute_percentage_error',smape_loss])

# %%
history = model.fit(X_train,y_train,epochs=30
                    ,batch_size=128,shuffle=True,use_multiprocessing=True,validation_data=(X_test,y_test))
# Out:
# Epoch 1/30
# 35/35 [==============================] - 19s 317ms/step - loss: 1.8993e-04 - mae: 0.0102 - mse: 1.8993e-04 - mean_absolute_percentage_error: 2.5689 - smape_loss: 2.0406 - val_loss: 0.0024 - val_mae: 0.0334 - val_mse: 0.0024 - val_mean_absolute_percentage_error: 5.5512 - val_smape_loss: 5.1732
# Epoch 2/30
# 35/35 [==============================] - 9s 261ms/step - loss: 1.6906e-04 - mae: 0.0097 - mse: 1.6906e-04 - mean_absolute_percentage_error: 2.4555 - smape_loss: 1.9648 - val_loss: 0.0023 - val_mae: 0.0317 - val_mse: 0.0023 - val_mean_absolute_percentage_error: 5.2614 - val_smape_loss: 4.8783
# Epoch 3/30
# 35/35 [==============================] - 9s 260ms/step - loss: 1.7382e-04 - mae: 0.0096 - mse: 1.7382e-04 - mean_absolute_percentage_error: 2.4534 - smape_loss: 1.9398 - val_loss: 0.0023 - val_mae: 0.0310 - val_mse: 0.0023 - val_mean_absolute_percentage_error: 5.1739 - val_smape_loss: 4.7837
# Epoch 4/30
# 35/35 [==============================] - 9s 259ms/step - loss: 1.7140e-04 - mae: 0.0097 - mse: 1.7140e-04 - mean_absolute_percentage_error: 2.4288 - smape_loss: 1.9361 - val_loss: 0.0023 - val_mae: 0.0336 - val_mse: 0.0023 - val_mean_absolute_percentage_error: 5.6404 - val_smape_loss: 5.2584
# Epoch 5/30
# 35/35 [==============================] - 9s 257ms/step - loss: 1.7821e-04 - mae: 0.0098 - mse: 1.7821e-04 - mean_absolute_percentage_error: 2.4841 - smape_loss: 1.9891 - val_loss: 0.0021 - val_mae: 0.0301 - val_mse: 0.0021 - val_mean_absolute_percentage_error: 5.0283 - val_smape_loss: 4.6374
# Epoch 6/30
# 35/35 [==============================] - 9s 256ms/step - loss: 1.6822e-04 - mae: 0.0096 - mse: 1.6822e-04 - mean_absolute_percentage_error: 2.4312 - smape_loss: 1.9198 - val_loss: 0.0024 - val_mae: 0.0333 - val_mse: 0.0024 - val_mean_absolute_percentage_error: 5.5653 - val_smape_loss: 5.1682
# Epoch 7/30
# 35/35 [==============================] - 9s 259ms/step - loss: 1.6087e-04 - mae: 0.0094 - mse: 1.6087e-04 - mean_absolute_percentage_error: 2.4105 - smape_loss: 1.9078 - val_loss: 0.0026 - val_mae: 0.0343 - val_mse: 0.0026 - val_mean_absolute_percentage_error: 5.7251 - val_smape_loss: 5.3305
# Epoch 8/30
# 35/35 [==============================] - 9s 257ms/step - loss: 1.6778e-04 - mae: 0.0097 - mse: 1.6778e-04 - mean_absolute_percentage_error: 2.4497 - smape_loss: 1.9477 - val_loss: 0.0021 - val_mae: 0.0316 - val_mse: 0.0021 - val_mean_absolute_percentage_error: 5.3963 - val_smape_loss: 4.9591
# Epoch 9/30
# 35/35 [==============================] - 9s 258ms/step - loss: 1.5175e-04 - mae: 0.0092 - mse: 1.5175e-04 - mean_absolute_percentage_error: 2.3224 - smape_loss: 1.8544 - val_loss: 0.0022 - val_mae: 0.0309 - val_mse: 0.0022 - val_mean_absolute_percentage_error: 5.1875 - val_smape_loss: 4.7752
# Epoch 10/30
# 35/35 [==============================] - 9s 257ms/step - loss: 1.5191e-04 - mae: 0.0092 - mse: 1.5191e-04 - mean_absolute_percentage_error: 2.3138 - smape_loss: 1.8447 - val_loss: 0.0023 - val_mae: 0.0306 - val_mse: 0.0023 - val_mean_absolute_percentage_error: 5.0217 - val_smape_loss: 4.6518
# Epoch 11/30
# 35/35 [==============================] - 9s 257ms/step - loss: 1.6138e-04 - mae: 0.0095 - mse: 1.6138e-04 - mean_absolute_percentage_error: 2.4396 - smape_loss: 1.9333 - val_loss: 0.0024 - val_mae: 0.0323 - val_mse: 0.0024 - val_mean_absolute_percentage_error: 5.4049 - val_smape_loss: 4.9713
# Epoch 12/30
# 35/35 [==============================] - 9s 258ms/step - loss: 1.4419e-04 - mae: 0.0090 - mse: 1.4419e-04 - mean_absolute_percentage_error: 2.3236 - smape_loss: 1.8392 - val_loss: 0.0022 - val_mae: 0.0320 - val_mse: 0.0022 - val_mean_absolute_percentage_error: 5.2975 - val_smape_loss: 4.9284
# Epoch 13/30
# 35/35 [==============================] - 9s 260ms/step - loss: 1.3720e-04 - mae: 0.0088 - mse: 1.3720e-04 - mean_absolute_percentage_error: 2.2206 - smape_loss: 1.7719 - val_loss: 0.0024 - val_mae: 0.0323 - val_mse: 0.0024 - val_mean_absolute_percentage_error: 5.3144 - val_smape_loss: 4.9411
# Epoch 14/30
# 35/35 [==============================] - 9s 258ms/step - loss: 1.5222e-04 - mae: 0.0091 - mse: 1.5222e-04 - mean_absolute_percentage_error: 2.2965 - smape_loss: 1.8334 - val_loss: 0.0023 - val_mae: 0.0326 - val_mse: 0.0023 - val_mean_absolute_percentage_error: 5.4490 - val_smape_loss: 5.0508
# Epoch 15/30
# 35/35 [==============================] - 9s 260ms/step - loss: 1.4154e-04 - mae: 0.0088 - mse: 1.4154e-04 - mean_absolute_percentage_error: 2.2071 - smape_loss: 1.7663 - val_loss: 0.0020 - val_mae: 0.0297 - val_mse: 0.0020 - val_mean_absolute_percentage_error: 4.8898 - val_smape_loss: 4.5498
# Epoch 16/30
# 35/35 [==============================] - 9s 260ms/step - loss: 1.4355e-04 - mae: 0.0088 - mse: 1.4355e-04 - mean_absolute_percentage_error: 2.2508 - smape_loss: 1.7837 - val_loss: 0.0024 - val_mae: 0.0324 - val_mse: 0.0024 - val_mean_absolute_percentage_error: 5.3529 - val_smape_loss: 4.9856
# Epoch 17/30
# 35/35 [==============================] - 9s 255ms/step - loss: 1.3731e-04 - mae: 0.0088 - mse: 1.3731e-04 - mean_absolute_percentage_error: 2.2247 - smape_loss: 1.7833 - val_loss: 0.0024 - val_mae: 0.0325 - val_mse: 0.0024 - val_mean_absolute_percentage_error: 5.3040 - val_smape_loss: 4.9651
# Epoch 18/30
# 35/35 [==============================] - 9s 255ms/step - loss: 1.5035e-04 - mae: 0.0090 - mse: 1.5035e-04 - mean_absolute_percentage_error: 2.2381 - smape_loss: 1.7840 - val_loss: 0.0019 - val_mae: 0.0288 - val_mse: 0.0019 - val_mean_absolute_percentage_error: 4.7977 - val_smape_loss: 4.4211
# Epoch 19/30
# 35/35 [==============================] - 9s 256ms/step - loss: 1.5044e-04 - mae: 0.0091 - mse: 1.5044e-04 - mean_absolute_percentage_error: 2.2387 - smape_loss: 1.7976 - val_loss: 0.0021 - val_mae: 0.0310 - val_mse: 0.0021 - val_mean_absolute_percentage_error: 5.2346 - val_smape_loss: 4.8086
# Epoch 20/30
# 35/35 [==============================] - 9s 255ms/step - loss: 1.4337e-04 - mae: 0.0090 - mse: 1.4337e-04 - mean_absolute_percentage_error: 2.3864 - smape_loss: 1.8794 - val_loss: 0.0022 - val_mae: 0.0315 - val_mse: 0.0022 - val_mean_absolute_percentage_error: 5.2971 - val_smape_loss: 4.8976
# Epoch 21/30
# 35/35 [==============================] - 9s 254ms/step - loss: 1.1917e-04 - mae: 0.0083 - mse: 1.1917e-04 - mean_absolute_percentage_error: 2.1163 - smape_loss: 1.6800 - val_loss: 0.0020 - val_mae: 0.0297 - val_mse: 0.0020 - val_mean_absolute_percentage_error: 4.9125 - val_smape_loss: 4.5637
# Epoch 22/30
# 35/35 [==============================] - 9s 255ms/step - loss: 1.2345e-04 - mae: 0.0083 - mse: 1.2345e-04 - mean_absolute_percentage_error: 2.1034 - smape_loss: 1.6726 - val_loss: 0.0022 - val_mae: 0.0304 - val_mse: 0.0022 - val_mean_absolute_percentage_error: 4.9711 - val_smape_loss: 4.6267
# Epoch 23/30
# 35/35 [==============================] - 9s 255ms/step - loss: 1.3078e-04 - mae: 0.0085 - mse: 1.3078e-04 - mean_absolute_percentage_error: 2.1407 - smape_loss: 1.7150 - val_loss: 0.0021 - val_mae: 0.0303 - val_mse: 0.0021 - val_mean_absolute_percentage_error: 4.9615 - val_smape_loss: 4.6136
# Epoch 24/30
# 35/35 [==============================] - 9s 253ms/step - loss: 1.2329e-04 - mae: 0.0081 - mse: 1.2329e-04 - mean_absolute_percentage_error: 2.0460 - smape_loss: 1.6348 - val_loss: 0.0020 - val_mae: 0.0302 - val_mse: 0.0020 - val_mean_absolute_percentage_error: 5.0606 - val_smape_loss: 4.6712
# Epoch 25/30
# 35/35 [==============================] - 9s 256ms/step - loss: 1.2681e-04 - mae: 0.0083 - mse: 1.2681e-04 - mean_absolute_percentage_error: 2.1211 - smape_loss: 1.6952 - val_loss: 0.0023 - val_mae: 0.0319 - val_mse: 0.0023 - val_mean_absolute_percentage_error: 5.2620 - val_smape_loss: 4.8975
# Epoch 26/30
# 35/35 [==============================] - 9s 260ms/step - loss: 1.1742e-04 - mae: 0.0079 - mse: 1.1742e-04 - mean_absolute_percentage_error: 1.9957 - smape_loss: 1.6042 - val_loss: 0.0021 - val_mae: 0.0309 - val_mse: 0.0021 - val_mean_absolute_percentage_error: 5.1174 - val_smape_loss: 4.7758
# Epoch 27/30
# 35/35 [==============================] - 9s 257ms/step - loss: 1.1797e-04 - mae: 0.0081 - mse: 1.1797e-04 - mean_absolute_percentage_error: 2.1029 - smape_loss: 1.6578 - val_loss: 0.0025 - val_mae: 0.0332 - val_mse: 0.0025 - val_mean_absolute_percentage_error: 5.5113 - val_smape_loss: 5.1144
# Epoch 28/30
# 35/35 [==============================] - 9s 255ms/step - loss: 1.2668e-04 - mae: 0.0084 - mse: 1.2668e-04 - mean_absolute_percentage_error: 2.0979 - smape_loss: 1.6871 - val_loss: 0.0019 - val_mae: 0.0295 - val_mse: 0.0019 - val_mean_absolute_percentage_error: 4.9005 - val_smape_loss: 4.5366
# Epoch 29/30
# 35/35 [==============================] - 9s 253ms/step - loss: 1.1810e-04 - mae: 0.0081 - mse: 1.1810e-04 - mean_absolute_percentage_error: 2.0568 - smape_loss: 1.6349 - val_loss: 0.0019 - val_mae: 0.0295 - val_mse: 0.0019 - val_mean_absolute_percentage_error: 4.9446 - val_smape_loss: 4.5567
# Epoch 30/30
# 35/35 [==============================] - 9s 253ms/step - loss: 1.3149e-04 - mae: 0.0085 - mse: 1.3149e-04 - mean_absolute_percentage_error: 2.1430 - smape_loss: 1.7184 - val_loss: 0.0020 - val_mae: 0.0297 - val_mse: 0.0020 - val_mean_absolute_percentage_error: 4.8759 - val_smape_loss: 4.5364

# %%
model.evaluate(X_test,y_test)
# Out:
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0020 - mae: 0.0297 - mse: 0.0020 - mean_absolute_percentage_error: 4.8759 - smape_loss: 4.5364
# [0.002044894266873598,
#  0.02970178797841072,
#  0.002044894266873598,
#  4.875934600830078,
#  4.536410808563232]

# %%
df_metrics = pd.DataFrame(history.history)
df_metrics.plot(subplots=True,figsize=(12,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
df_metrics
# Out:
#         loss       mae       mse  mean_absolute_percentage_error  smape_loss  \
# 0   0.000190  0.010221  0.000190                        2.568944    2.040632
# 1   0.000169  0.009748  0.000169                        2.455456    1.964762
# 2   0.000174  0.009645  0.000174                        2.453393    1.939836
# 3   0.000171  0.009684  0.000171                        2.428819    1.936084
# 4   0.000178  0.009836  0.000178                        2.484091    1.989125
# 5   0.000168  0.009571  0.000168                        2.431249    1.919787
# 6   0.000161  0.009424  0.000161                        2.410457    1.907783
# 7   0.000168  0.009665  0.000168                        2.449718    1.947708
# 8   0.000152  0.009203  0.000152                        2.322447    1.854379
# 9   0.000152  0.009157  0.000152                        2.313784    1.844677
# 10  0.000161  0.009541  0.000161                        2.439583    1.933335
# 11  0.000144  0.009020  0.000144                        2.323606    1.839171
# 12  0.000137  0.008766  0.000137                        2.220590    1.771859
# 13  0.000152  0.009106  0.000152                        2.296547    1.833363
# 14  0.000142  0.008828  0.000142                        2.207137    1.766330
# 15  0.000144  0.008811  0.000144                        2.250750    1.783740
# 16  0.000137  0.008818  0.000137                        2.224703    1.783324
# 17  0.000150  0.008957  0.000150                        2.238064    1.784003
# 18  0.000150  0.009066  0.000150                        2.238722    1.797609
# 19  0.000143  0.009017  0.000143                        2.386408    1.879386
# 20  0.000119  0.008262  0.000119                        2.116318    1.680030
# 21  0.000123  0.008259  0.000123                        2.103431    1.672615
# 22  0.000131  0.008512  0.000131                        2.140711    1.715046
# 23  0.000123  0.008145  0.000123                        2.045992    1.634848
# 24  0.000127  0.008345  0.000127                        2.121121    1.695156
# 25  0.000117  0.007943  0.000117                        1.995655    1.604241
# 26  0.000118  0.008136  0.000118                        2.102930    1.657848
# 27  0.000127  0.008390  0.000127                        2.097927    1.687117
# 28  0.000118  0.008099  0.000118                        2.056775    1.634920
# 29  0.000131  0.008542  0.000131                        2.143034    1.718422
#
#     val_loss   val_mae   val_mse  val_mean_absolute_percentage_error  \
# 0   0.002436  0.033411  0.002436                            5.551243
# 1   0.002261  0.031702  0.002261                            5.261419
# 2   0.002266  0.031049  0.002266                            5.173890
# 3   0.002345  0.033642  0.002345                            5.640427
# 4   0.002074  0.030089  0.002074                            5.028268
# 5   0.002425  0.033329  0.002425                            5.565318
# 6   0.002582  0.034278  0.002582                            5.725126
# 7   0.002098  0.031580  0.002098                            5.396326
# 8   0.002198  0.030929  0.002198                            5.187482
# 9   0.002255  0.030572  0.002255                            5.021686
# 10  0.002394  0.032338  0.002394                            5.404890
# 11  0.002248  0.031991  0.002248                            5.297460
# 12  0.002416  0.032290  0.002416                            5.314356
# 13  0.002338  0.032590  0.002338                            5.448983
# 14  0.001983  0.029734  0.001983                            4.889814
# 15  0.002385  0.032416  0.002385                            5.352855
# 16  0.002405  0.032496  0.002405                            5.304014
# 17  0.001931  0.028818  0.001931                            4.797725
# 18  0.002121  0.030973  0.002121                            5.234635
# 19  0.002179  0.031540  0.002179                            5.297138
# 20  0.001984  0.029723  0.001984                            4.912517
# 21  0.002159  0.030368  0.002159                            4.971106
# 22  0.002117  0.030261  0.002117                            4.961536
# 23  0.001996  0.030246  0.001996                            5.060589
# 24  0.002264  0.031897  0.002264                            5.261982
# 25  0.002086  0.030946  0.002086                            5.117412
# 26  0.002523  0.033241  0.002523                            5.511276
# 27  0.001942  0.029514  0.001942                            4.900500
# 28  0.001913  0.029478  0.001913                            4.944604
# 29  0.002045  0.029702  0.002045                            4.875935
#
#     val_smape_loss
# 0         5.173178
# 1         4.878329
# 2         4.783709
# 3         5.258407
# 4         4.637365
# 5         5.168244
# 6         5.330475
# 7         4.959136
# 8         4.775191
# 9         4.651807
# 10        4.971250
# 11        4.928374
# 12        4.941102
# 13        5.050816
# 14        4.549769
# 15        4.985605
# 16        4.965085
# 17        4.421096
# 18        4.808568
# 19        4.897556
# 20        4.563658
# 21        4.626694
# 22        4.613639
# 23        4.671221
# 24        4.897470
# 25        4.775844
# 26        5.114448
# 27        4.536565
# 28        4.556662
# 29        4.536410

# %%
model.predict(X[index:])[-1]*max(data['Adj Close'])
# Out:
# array([28.1253], dtype=float32)

# %%
from matplotlib import pyplot as plt 
plt.plot(model.predict(X_test)[0:,0])
plt.plot(y_test)

# %%
df = pd.DataFrame({
    "predicted":model.predict(X_test)[0:,0],
    "real":y_test})

# %%
df['diff'] = df['real'] - df['predicted']

# %%
# negative good -> we under predicted
# positive bad  -> we over predicted 
df.describe()
# Out:
#         predicted        real        diff
# count  490.000000  490.000000  490.000000
# mean     0.431775    0.458179    0.026404
# std      0.180805    0.213875    0.036749
# min      0.101913    0.097193   -0.029416
# 25%      0.273675    0.269012   -0.001242
# 50%      0.439228    0.454999    0.009858
# 75%      0.551889    0.595473    0.046453
# max      0.838974    0.949063    0.145156

# %%
plt.scatter(x=np.arange(len(X_test[0:50])),y=model.predict(X_test)[0:50] *max(data['Adj Close']))
plt.scatter(x=np.arange(len(X_test[0:50])),y=y_test[0:50] *max(data['Adj Close']))

# %%
a =  min(data['Adj Close'])
b =  max(data['Adj Close'])

# %%
a
# Out:
# 8.300000190734863

# %%
b
# Out:
# 91.29000091552734

# %%
model.save("models/goodModelDividedByMaxAdjClose.h5")
